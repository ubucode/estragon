# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mpld3
from mpld3 import plugins

def get_OFS(recipes):
   N=0
   res=[]   

   for r in recipes:
      oeuf=0
      farine=0
      sucre=0
      for ing in r['ingredients']:
         if "oeuf" in ing['content']:  oeuf=ing["quantity"] 
         if "farine" in ing['content']: farine=ing["quantity"]
         if "sucre" in  ing['content']: sucre=ing["quantity"]
      if (farine * oeuf * sucre): 
       f=farine/oeuf
       s=sucre/oeuf
       N+=1
       res.append([r['name'], f, s])
   return res

# %%
fname="/home/kodda/Dropbox/recipes_space/750g_recipes.json"
recipes=json.load(open(fname))
res=get_OFS(recipes)

print(res)
# Out:
# [["Pain d'épices", 130.0, 20.0], ['Mini tendrement chocolat', 26.666666666666668, 0.3333333333333333], ['Gâteau aux pommes trop facile', 150.0, 100.0], ['Gâteau tout chocolat', 16.666666666666668, 33.333333333333336], ['Cake Pops jambon et fromage', 60.0, 20.0], ['Gâteau au chocolat inratable', 25.0, 31.25], ['Mug cake au chocolat', 20.0, 20.0], ['Gâteau de crêpes au Nutella', 100.0, 20.0], ['Gâteau DARK VADOR STAR WARS', 3.0, 250.0], ['Comment réaliser un gâteau au noix ?', 23.333333333333332, 50.0], ['Gâteau au chocolat noir et pointe de miel', 20.0, 25.0], ['Gâteau au chocolat au micro-ondes facile', 25.0, 25.0], ['Fondant au chocolat', 16.666666666666668, 41.666666666666664], ['Gâteau aux poires', 50.0, 1.0], ['Gâteau des Rois', 100.0, 5.0], ['Gâteau au yaourt', 1.0, 0.3333333333333333], ['Beignets de crevettes', 150.0, 50.0], ['Pancakes', 100.0, 0.3333333333333333], ['Fondant coeur chocolat', 6.666666666666667, 26.666666666666668], ['Gâteau aux pommes facile à réaliser', 50.0, 5
# ...

# %%
css = """
table
{
  border-collapse: collapse;
}
th
{
  color: #ffffff;
  background-color: #000000;
}
td
{
  background-color: #cccccc;
}
table, th, td
{
  font-family:Arial, Helvetica, sans-serif;
  border: 1px solid black;
  text-align: right;
}
"""

fig, ax = plt.subplots()
ax.grid(True, alpha=0.3)

N = len(res)
df = pd.DataFrame(index=range(N))
df['x'] = np.array([r[1] for r in res])
df['y'] = np.array([r[2] for r in res])
df['label'] = np.array([r[0] for r in res])

labels = []
for i in range(N):
    label = df.iloc[[i], :].T
    label.columns = [res[i][0]]
    # .to_html() is unicode; so make leading 'u' go away with str()
    labels.append(str(label.to_html()))

points = ax.plot(df.x, df.y, 'o', color='b',
                 mec='k', ms=15, mew=1, alpha=.6)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('HTML tooltips', size=20)

tooltip = plugins.PointHTMLTooltip(points[0], labels,
                                   voffset=10, hoffset=10, css=css)
plugins.connect(fig, tooltip)

mpld3.display(fig)
# Out:
# <style>
#
# table
# {
#   border-collapse: collapse;
# }
# th
# {
#   color: #ffffff;
#   background-color: #000000;
# }
# td
# {
#   background-color: #cccccc;
# }
# table, th, td
# {
#   font-family:Arial, Helvetica, sans-serif;
#   border: 1px solid black;
#   text-align: right;
# }
#
# </style>
#
# <div id="fig_el3391406326159024567399383129"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# ...
